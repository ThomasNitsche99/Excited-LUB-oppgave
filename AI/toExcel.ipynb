# %%
import pandas as pd

# Load CSV file
csv_file = "KRISTIANIA_LUBER.csv"  # Replace with your CSV file path
df = pd.read_csv(csv_file)

# Save as Excel file
excel_file = "data.xlsx"  # Replace with your desired Excel file name
df.to_excel(excel_file, index=False)  # index=False removes the index column

print(f"CSV successfully converted to {excel_file}")
# Out:
# CSV successfully converted to data.xlsx
